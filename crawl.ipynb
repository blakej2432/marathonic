# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
url = "http://www.roadrun.co.kr/schedule/list.php"
response = requests.get(url)
response.encoding = 'euc-kr'  # 또는 'euc-kr' 시도 (확인 필요)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
target_table = soup.select('body > p > table > tr:nth-of-type(3) >td')

# %%
p = target_table[0].find('p', attrs={'align': 'left'})

# %%
trs = p.select('table > tr > td > table:nth-of-type(3) >tr')

# %%
trs[0].find_all('td')[0].get_text(strip=True).split('(')[0].strip()
# Out:
# '5/3'

# %%
for tr in trs:
    try: 
        tds = tr.find_all('td')
        # print(tds)
        if len(tds) < 4:
            continue
    except:
        print("예외발생")

# %%
race_data = []

# %%
from datetime import datetime


for tr in trs:
    try:
        tds = tr.find_all('td')
        if len(tds) < 4:
            continue  # 필드가 부족하면 스킵

        # 날짜 추출 및 포맷 변경
        date_raw = tds[0].get_text(strip=True).split('(')[0].strip()  # "5/3"
        # date_raw = tds[0].get_text()
        try:
            date_obj = datetime.strptime(date_raw, "%m/%d")
            race_date = f"2025-{date_obj.month:02}-{date_obj.day:02}"  # 연도는 임의 설정
        except:
            continue  # 날짜 형식이 이상하면 건너뜀
        
        # 접수중 여부 확인 (접수중이면 <img> 있음)
        is_open = bool(tds[0].find('img'))

        # 대회명
        race_title = tds[1].find('a').get_text(strip=True)

        # 코스 타입
        course_font = tds[1].find('font', attrs={'color': '#990000'})
        course_type = course_font.get_text(strip=True) if course_font else ''

        # 지역
        location = tds[2].get_text(strip=True)
        
        # 홈페이지 url
        home_url = ''
        for a in tds[3].find_all('a', href=True):
            if a['href'].startswith('http'):
                home_url = a['href']
                break

        race_data.append({
            "대회제목": race_title,
            "대회날짜": race_date,
            "지역": location,
            "코스타입": course_type,
            "접수중여부": "접수중" if is_open else "",
            "홈페이지": home_url
        })

    except Exception as e:
        # 디버깅 필요하면 print(e)
        continue

# %%
race_data
# Out:
# [{'대회제목': '제25회 여성마라톤',
#   '대회날짜': '2025-05-03',
#   '지역': '평화의공원 평화광장',
#   '코스타입': '10km,5km,3km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.womenmarathon.co.kr/'},
#  {'대회제목': '2025 서울 유아차 런',
#   '대회날짜': '2025-05-03',
#   '지역': '광화문광장',
#   '코스타입': '5km',
#   '접수중여부': '',
#   '홈페이지': 'http://seoulstrollerrun.co.kr/apply/guide.php'},
#  {'대회제목': '제20회 보성 녹차 마라톤',
#   '대회날짜': '2025-05-03',
#   '지역': '보성공설운동장',
#   '코스타입': '풀,하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://boseong.run1080.com/index.php?sub=sub01_m01_c01'},
#  {'대회제목': '2025 우리은행배 제물포르네상스 국제 마라톤',
#   '대회날짜': '2025-05-04',
#   '지역': '인천 상상플랫폼',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://run.ito.or.kr'},
#  {'대회제목': '2025 한강 하프 마라톤',
#   '대회날짜': '2025-05-04',
#   '지역': '상암월드컵공원 평화광장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.seoulhalfrun.kr/'},
#  {'대회제목': '제23회 불,수,사,도,북5개산 종주',
#   '대회날짜': '2025-05-04',
#   '지역': '원자력병원.백세문',
#   '코스타입': '42km,13km',
#   '접수중여부': '',
#   '홈페이지': 'http://koreatrail.net/home/main.php?link=csno&csno=20170613133750'},
#  {'대회제목': '소아암환우돕기 제22회 서울시민마라톤',
#   '대회날짜': '2025-05-04',
#   '지역': '여의도 한강공원 물빛광장',
#   '코스타입': '하프,10km,5km,3km걷기',
#   '접수중여부': '',
#   '홈페이지': 'http://soaam.runningdr.co.kr'},
#  {'대회제목': '제10회 기적의 마라톤 with 이봉주',
#   '대회날짜': '2025-05-05',
#   '지역': '대전 유성 도룡동 632',
#   '코스타입': '5km',
#   '접수중여부': '',
#   '홈페이지': 'http://todagmarathon.com/online'},
#  {'대회제목': '버닝런 2025(마감)',
#   '대회날짜': '2025-05-06',
#   '지역': '여의도 한강공원 물빛무대 앞 광장',
#   '코스타입': '10km,7km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.burningrun.co.kr/'},
#  {'대회제목': '제1회 화이트런',
#   '대회날짜': '2025-05-10',
#   '지역': '상암동 평화의광장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://whiterun.kr'},
#  {'대회제목': '2025 도시가스 온런 광주',
#   '대회날짜': '2025-05-10',
#   '지역': '광주월드컵경기장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://citygasonrun.com'},
#  {'대회제목': '제26회 화성 효 마라톤',
#   '대회날짜': '2025-05-10',
#   '지역': '화성종합경기타운',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://hscity-marathon.com/index.php'},
#  {'대회제목': '제18회 대전한밭벌울트라마라톤',
#   '대회날짜': '2025-05-10',
#   '지역': '대전시 서구 둔산대로 169',
#   '코스타입': '100km,50km',
#   '접수중여부': '',
#   '홈페이지': 'http://dhultra.kr'},
#  {'대회제목': 'BUSAN 50K',
#   '대회날짜': '2025-05-10',
#   '지역': '신라대학교 대운동장',
#   '코스타입': '50K, 24K, 12K,백양산 둘레길 22K, 키즈런',
#   '접수중여부': '',
#   '홈페이지': 'http://busan-50k.imweb.me/'},
#  {'대회제목': '제4회 전국무등산무돌길완주대회',
#   '대회날짜': '2025-05-10',
#   '지역': '광주역광장, 무돌길일원',
#   '코스타입': '51.8km, 43km, 33km, 23km, 13km, 5.18km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.mudolgil518.or.kr/'},
#  {'대회제목': '2025 가정의달 하하호호 마라톤',
#   '대회날짜': '2025-05-10',
#   '지역': '안양천 신정교하부육상트랙구장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://xn--o39a84ke5dgxc710an6as16b.kr/'},
#  {'대회제목': '2025 전마협창단24주년기념 금산무료초청마라톤',
#   '대회날짜': '2025-05-11',
#   '지역': '금산인삼엑스포주차장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?code=1487'},
#  {'대회제목': '2025 전국의병 마라톤',
#   '대회날짜': '2025-05-11',
#   '지역': '의령공설운동장',
#   '코스타입': '풀,하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.urmarathon.com'},
#  {'대회제목': '댕댕트레킹 2025',
#   '대회날짜': '2025-05-17',
#   '지역': '정선 하이원',
#   '코스타입': '10km,6Km,4Km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://dangdangtrekking.com'},
#  {'대회제목': '2025 사랑의 쌀나누기 기금마련마라톤',
#   '대회날짜': '2025-05-17',
#   '지역': '안산호수공원 일대 (중앙무대)',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://ansanmarathon.co.kr'},
#  {'대회제목': '제3회 서울한강울트라마라톤',
#   '대회날짜': '2025-05-17',
#   '지역': '서울성북구 석관동 우이천다목적',
#   '코스타입': '100km,50km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.100ultraclub.kr/'},
#  {'대회제목': '2025 서울신문 하프마라톤',
#   '대회날짜': '2025-05-17',
#   '지역': '상암 월드컵공원 평화의광장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://marathon.seoul.co.kr'},
#  {'대회제목': '컬처런 2025 영종국제도시 마라톤',
#   '대회날짜': '2025-05-17',
#   '지역': '인천 중구 씨사이드파크 일원(',
#   '코스타입': '하프,10km,5km,가족런,중구 구민',
#   '접수중여부': '',
#   '홈페이지': 'http://culturerun.net'},
#  {'대회제목': '2025 무의도구석구석 국제트레일런대회',
#   '대회날짜': '2025-05-18',
#   '지역': '하나개해수욕장',
#   '코스타입': '트레일런 12km,트레일런 25km',
#   '접수중여부': '',
#   '홈페이지': 'http://cafe.naver.com/matrailrun'},
#  {'대회제목': '제3회 여의도 밤섬마라톤',
#   '대회날짜': '2025-05-18',
#   '지역': '여의도공원 문화의마당',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://bamseom.com/'},
#  {'대회제목': '2025 굽네 오븐런 5K',
#   '대회날짜': '2025-05-18',
#   '지역': '상암 월드컵공원 평화의 광장',
#   '코스타입': '5km',
#   '접수중여부': '',
#   '홈페이지': 'http://runable.me/product/1883?comp=1880'},
#  {'대회제목': '2025 대전 서구청장배 마라톤',
#   '대회날짜': '2025-05-18',
#   '지역': '대전엑스포시민광장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?sub=sub01_m02_c01&code=1474'},
#  {'대회제목': '남한산성 트레일런',
#   '대회날짜': '2025-05-18',
#   '지역': '산성로타리',
#   '코스타입': '20km,10km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.mtrailrun.kr'},
#  {'대회제목': '제 2회 남해 다랑논 마라톤',
#   '대회날짜': '2025-05-24',
#   '지역': '남해군 서면 남서대로 2647',
#   '코스타입': '10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://runny.world/'},
#  {'대회제목': '제25회 5.18마라톤',
#   '대회날짜': '2025-05-24',
#   '지역': '국립5·18민주묘지 광장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://518run.com'},
#  {'대회제목': '2025 라이트업! 키즈레이스',
#   '대회날짜': '2025-05-24',
#   '지역': '강남 대치유수지 체육공원',
#   '코스타입': '5km,초등부, 영유아부',
#   '접수중여부': '',
#   '홈페이지': 'http://goodrunner.co.kr/product/detail.html?product_no=5405'},
#  {'대회제목': '제30회 바다의 날 마라톤',
#   '대회날짜': '2025-05-24',
#   '지역': '상암 평화의 공원 평화광장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://badamarathon.com'},
#  {'대회제목': '2025 제24회 제주국제울트라마라톤',
#   '대회날짜': '2025-05-24',
#   '지역': '제주시 탑동광장',
#   '코스타입': '100km,200km,80km 트레일러닝',
#   '접수중여부': '',
#   '홈페이지': 'http://www.kumf.kr'},
#  {'대회제목': '제22회 보령머드임해마라톤',
#   '대회날짜': '2025-05-24',
#   '지역': '대천해수욕장1지구 제2주차장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://brrun.co.kr/'},
#  {'대회제목': '2025 옥스팜 트레일워커',
#   '대회날짜': '2025-05-24',
#   '지역': '인제군 일대',
#   '코스타입': '100km,50km,25km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.oxfamtrailwalker.or.kr'},
#  {'대회제목': '제29회 제주국제관광마라톤축제',
#   '대회날짜': '2025-05-25',
#   '지역': '구좌생활체육공원',
#   '코스타입': '풀,하프,10km',
#   '접수중여부': '',
#   '홈페이지': 'http://jejumarathon.com/main/'},
#  {'대회제목': '2025 백양산숲길건강달리기',
#   '대회날짜': '2025-05-25',
#   '지역': '학생문화회관(성지곡)',
#   '코스타입': '하프,10km,6km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.bsama.co.kr/'},
#  {'대회제목': '2025 강북구청장배 마라톤',
#   '대회날짜': '2025-05-25',
#   '지역': '우이천변(한일병원 건너편)',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://cafe.daum.net/Kangmaclub/IXtE'},
#  {'대회제목': '2025 구리 유채꽃 마라톤',
#   '대회날짜': '2025-05-25',
#   '지역': '구리 한강시민공원',
#   '코스타입': '하프,10km,5km,걷기',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://guriflowerrun.kr/'},
#  {'대회제목': '2025 무주반딧불 하프 마라톤대회',
#   '대회날짜': '2025-05-25',
#   '지역': '무주등나무운동장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?code=1477'},
#  {'대회제목': '2025년 독도수호 동호인마라톤',
#   '대회날짜': '2025-05-25',
#   '지역': '경주시 서천둔치',
#   '코스타입': '10km,28km 혼성릴레이',
#   '접수중여부': '',
#   '홈페이지': 'http://gma1111.org'},
#  {'대회제목': '제5회 영등포구청장배 육상대회 (마감)',
#   '대회날짜': '2025-05-25',
#   '지역': '안양천 신정교 육상트랙구장',
#   '코스타입': '10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://cafe.naver.com/ydprun1/565'},
#  {'대회제목': '제35회지리산화대종주CLIMBATHON',
#   '대회날짜': '2025-05-25',
#   '지역': '화엄사3시성삼재4시',
#   '코스타입': '48km,40km,34km,21km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.koreatrail.net/home/main.php?link=csno&csno=20150930092416'},
#  {'대회제목': '런데이 5월 마라톤 [미션RUNDAY]',
#   '대회날짜': '2025-05-31',
#   '지역': '전국 어디서나, 런데이 앱에서',
#   '코스타입': '하프,10km,5km,3km,7km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://rundayclub.shopby.co.kr/product-detail?productNo=129667822&preview=true'},
#  {'대회제목': '2025 지구런 : 더 피스로드',
#   '대회날짜': '2025-05-31',
#   '지역': '여의도공원 문화의마당',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://earthrun.kr'},
#  {'대회제목': '제11회 I LOVE 방송대 마라톤',
#   '대회날짜': '2025-05-31',
#   '지역': '상암동 월드컵공원 평화광장',
#   '코스타입': '10km,5.31km',
#   '접수중여부': '',
#   '홈페이지': 'http://runbs.co.kr'},
#  {'대회제목': '제12회 거제100K',
#   '대회날짜': '2025-05-31',
#   '지역': '거제스포츠파크',
#   '코스타입': '66K / 40K / 30K / 20K',
#   '접수중여부': '',
#   '홈페이지': 'http://geoje100.creatorlink.net/'},
#  {'대회제목': '2025 한밭 런앤워크 페스티벌',
#   '대회날짜': '2025-05-31',
#   '지역': '대전 엑스포 시민광장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://hrun.co.kr'},
#  {'대회제목': '2025 서천한산모시마라톤',
#   '대회날짜': '2025-05-31',
#   '지역': '서천종합운동장',
#   '코스타입': '10km,5km,가족런,커플런',
#   '접수중여부': '',
#   '홈페이지': 'http://mosirun.co.kr'},
#  {'대회제목': '제18회 강남구 육상연맹 회장배 육상대회',
#   '대회날짜': '2025-05-31',
#   '지역': '대치유수지 체육공원',
#   '코스타입': '10km,10K커플런,10K마니아,10K버추얼런',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://comport11.oopy.io/'},
#  {'대회제목': '커피 빵빵런 in 강릉',
#   '대회날짜': '2025-06-01',
#   '지역': '강릉 경포호수광장',
#   '코스타입': '10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://coffeebbangrun.com'},
#  {'대회제목': '2025 전마협 창단 24주년 기념 월드런 마라톤',
#   '대회날짜': '2025-06-01',
#   '지역': '대전엑스포다리 밑 잔디광장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?code=1480'},
#  {'대회제목': '제10회 너릿재마라톤',
#   '대회날짜': '2025-06-01',
#   '지역': '화순 셀레브 카페 입구',
#   '코스타입': '8km,16km,24km',
#   '접수중여부': '',
#   '홈페이지': 'http://marathonworld.kr/'},
#  {'대회제목': '희망드림-제22회 새벽강변 국제마라톤',
#   '대회날짜': '2025-06-01',
#   '지역': '상암동 평화의광장',
#   '코스타입': '하프,10km,5km,5km가족런',
#   '접수중여부': '',
#   '홈페이지': 'http://amarunsb.com/'},
#  {'대회제목': '물사랑낙동강200km울트라마라톤',
#   '대회날짜': '2025-06-06',
#   '지역': '을숙도물문화센터',
#   '코스타입': '100km,200km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.ndru200.co.kr/'},
#  {'대회제목': '2025 희망 서울 마라톤',
#   '대회날짜': '2025-06-07',
#   '지역': '평화의 공원 평화광장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://hoperun.kr/'},
#  {'대회제목': '2025 HARURUN 하루런',
#   '대회날짜': '2025-06-07',
#   '지역': '미사경정공원',
#   '코스타입': '10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.harurun.co.kr'},
#  {'대회제목': '제27회 양평이봉주마라톤겸 경인일보남한강마라톤',
#   '대회날짜': '2025-06-07',
#   '지역': '양평강상체육공원',
#   '코스타입': '하프,10km,5km,커플런',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.hangangmarathon.net'},
#  {'대회제목': 'SNTR 성남누비길트레일러닝대회',
#   '대회날짜': '2025-06-07',
#   '지역': '동서울대학교',
#   '코스타입': '75km,40km',
#   '접수중여부': '',
#   '홈페이지': 'http://ktra.kr'},
#  {'대회제목': '제1회 전주마라톤',
#   '대회날짜': '2025-06-07',
#   '지역': '전주월드컵경기장 광장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://jjrun1.kr'},
#  {'대회제목': '2025 춘천봄내마라톤',
#   '대회날짜': '2025-06-07',
#   '지역': '춘천시청 앞',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://ccpmarathon.kr'},
#  {'대회제목': '제23회 청광종주 TRAILRUNNING',
#   '대회날짜': '2025-06-07',
#   '지역': '양재동화물터미널,하오고개',
#   '코스타입': '26km,14km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.koreatrail.net/home/main.php?link=csno&csno=20191016122754'},
#  {'대회제목': '2025 청춘런',
#   '대회날짜': '2025-06-08',
#   '지역': '상암동 월드컵경기장',
#   '코스타입': '10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.youthrun.co.kr/'},
#  {'대회제목': '2025 빵트레일런',
#   '대회날짜': '2025-06-14',
#   '지역': '강원도 정선 하이원 리조트',
#   '코스타입': '20km,12km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://bbangtrailrun.com/'},
#  {'대회제목': '2025 인천광역시육상연맹회장배 마라톤대회',
#   '대회날짜': '2025-06-14',
#   '지역': '정서진 아라타워 일원',
#   '코스타입': '하프,10km,5km,가족런,커플런',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://incheonmarathon.net'},
#  {'대회제목': '제15회 국민행복마라톤',
#   '대회날짜': '2025-06-14',
#   '지역': '서울 뚝섬한강공원 수변광장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.irunman.kr'},
#  {'대회제목': '2025 제9회 포항철강마라톤',
#   '대회날짜': '2025-06-14',
#   '지역': '포항 영일대 해수욕장 일원',
#   '코스타입': '10km,5km,5km 학생',
#   '접수중여부': '',
#   '홈페이지': 'http://phsteelrun.com'},
#  {'대회제목': '2025 제주오름 트레일러닝',
#   '대회날짜': '2025-06-14',
#   '지역': '서귀포시 녹산로',
#   '코스타입': '10km,32km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.jejuoreumtrailrunning.com'},
#  {'대회제목': '2025년 제22회 광주빛고을울트라100km마',
#   '대회날짜': '2025-06-14',
#   '지역': '광주 광역시청 야외음악당',
#   '코스타입': '100km,50km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://gj100k.org'},
#  {'대회제목': '제2회 긍정의힘 마라톤',
#   '대회날짜': '2025-06-15',
#   '지역': '여의도공원 문화의마당',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.powerrun.kr/'},
#  {'대회제목': '제20회 울릉도 국제 마라톤대회',
#   '대회날짜': '2025-06-15',
#   '지역': '울릉 예술 문화 체험장',
#   '코스타입': '풀,하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://ulmarathon.co.kr/'},
#  {'대회제목': '2025 김해 숲길마라톤',
#   '대회날짜': '2025-06-15',
#   '지역': '김해운동장 및 숲길 일원',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.supgil.com'},
#  {'대회제목': '수원트레일레이스',
#   '대회날짜': '2025-06-15',
#   '지역': '효행공원',
#   '코스타입': '25K,18K',
#   '접수중여부': '',
#   '홈페이지': 'http://runsuwon.com'},
#  {'대회제목': '<팀재국후원>대전보문산트레일',
#   '대회날짜': '2025-06-15',
#   '지역': '오월드주차장',
#   '코스타입': '15km,10km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.mtrailrun.kr'},
#  {'대회제목': '제21회 영덕 해변 전국마라톤대회',
#   '대회날짜': '2025-06-15',
#   '지역': '고래불해수욕장일원',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.runmp.kr'},
#  {'대회제목': '제22회 춘천호반마라톤대회',
#   '대회날짜': '2025-06-15',
#   '지역': '춘천시 송암종합운동장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://kw-marathon.com/'},
#  {'대회제목': '제13회 광명시 육상연맹회장배 건강달리기',
#   '대회날짜': '2025-06-15',
#   '지역': '광명찬빛광장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://gmaf.kr/'},
#  {'대회제목': '2025 스피드업 라이트 금산 마라톤 대회',
#   '대회날짜': '2025-06-21',
#   '지역': '금산인삼엑스포주차장',
#   '코스타입': '5km,11.8km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?code=1490'},
#  {'대회제목': '제14회 울산태화강울트라마라톤',
#   '대회날짜': '2025-06-21',
#   '지역': '태화강둔치(태화다리 밑)',
#   '코스타입': '50km,100km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://utu100.kr'},
#  {'대회제목': '2025 월드비전 글로벌 6K 마라톤',
#   '대회날짜': '2025-06-21',
#   '지역': '서울 상암 월드컵공원',
#   '코스타입': '10km,6km',
#   '접수중여부': '',
#   '홈페이지': 'http://global6kforwater.com/frt/application/applicationOverview.do?CMPT_AREA_TYPE=1&utm_source=marathononline&utm_medium=referral&utm_campaign=25Running6K'},
#  {'대회제목': '람사르습지 밤섬런(구, 온에어런)',
#   '대회날짜': '2025-06-22',
#   '지역': '여의도공원 문화의마당',
#   '코스타입': '10km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.bamseomrun.kr'},
#  {'대회제목': '2025 전국블루베리마라톤축제',
#   '대회날짜': '2025-06-22',
#   '지역': '정읍시 입암면 대흥초 운동장',
#   '코스타입': '10km,5km,5km가족부(2인1조),10km단체전(3인1조)',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://dhrun.kr'},
#  {'대회제목': '2025 용인마라톤',
#   '대회날짜': '2025-06-22',
#   '지역': '용인시청앞',
#   '코스타입': '10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://yonginmarathon.net'},
#  {'대회제목': '청계산 일주TRAIL RUNNING',
#   '대회날짜': '2025-06-22',
#   '지역': '양재동 화물터미널',
#   '코스타입': '10km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.koreatrail.net/home/main.php?link=event&einc=eindex&csno=20190812093657&opp=20240621135834'},
#  {'대회제목': '2025 행복안전동행 마라톤',
#   '대회날짜': '2025-06-28',
#   '지역': '여의도 공원 문화의 마당',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://happysaferun.kr/'},
#  {'대회제목': '2025 보은 속리산 말티재 힐링 알몸 마라톤',
#   '대회날짜': '2025-06-28',
#   '지역': '보은군 속리산 말티고개',
#   '코스타입': '10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?code=1478'},
#  {'대회제목': '2025 광제산 트레일 런',
#   '대회날짜': '2025-07-13',
#   '지역': '진주 광제산 입구 주차장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.trailrun.kr'},
#  {'대회제목': '2025 태종대전국마라톤',
#   '대회날짜': '2025-07-20',
#   '지역': '태종대공원',
#   '코스타입': '하프,14km,7km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.bsama.co.kr/'},
#  {'대회제목': '제7회 안산.인왕산,북악산 climbathon',
#   '대회날짜': '2025-07-20',
#   '지역': '연세대학교정문',
#   '코스타입': '10km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://koreatrail.net'},
#  {'대회제목': '제2회 쿨밸리 트레일레이스',
#   '대회날짜': '2025-08-02',
#   '지역': '장수종합경기장',
#   '코스타입': '하프',
#   '접수중여부': '',
#   '홈페이지': 'http://rocknrun.kr'},
#  {'대회제목': '김완기배제36회지리산 화대종주',
#   '대회날짜': '2025-08-15',
#   '지역': '화엄사.성산재.중산리',
#   '코스타입': '48km,40km,34km,21km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://koreatrail.net'},
#  {'대회제목': '2025 금수산트레일 러닝대회',
#   '대회날짜': '2025-08-24',
#   '지역': '청풍리조트',
#   '코스타입': '22km,13km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.runnerking.com'},
#  {'대회제목': '제4회 선샤인 런',
#   '대회날짜': '2025-08-30',
#   '지역': '잠실한강공원 청소년광장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.irunman.kr'},
#  {'대회제목': '제2회 삼척시장배 단방산 숲길 마라톤',
#   '대회날짜': '2025-08-30',
#   '지역': '삼척 궁촌항',
#   '코스타입': '10km,5km,15km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?code=1489'},
#  {'대회제목': '제19회 순천만울트라마라톤',
#   '대회날짜': '2025-09-06',
#   '지역': '순천동천천변공원',
#   '코스타입': '100km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.scultra100.net'},
#  {'대회제목': '2025 양양 강변 전국마라톤',
#   '대회날짜': '2025-09-13',
#   '지역': '양양군 웰컴센터 및 남대천 일원',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://yrun.co.kr'},
#  {'대회제목': '2025 금산인삼축제 투데이 마라톤(토)',
#   '대회날짜': '2025-09-13',
#   '지역': '금산군 금산인삼엑스포주차장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?sub=sub01_m02_c01&code=1485'},
#  {'대회제목': '제11회 시각장애인과 함께하는 어울림 마라톤',
#   '대회날짜': '2025-09-13',
#   '지역': '상암월드컵공원 평화광장',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.sbsa.or.kr'},
#  {'대회제목': '2025 금산인삼축제 투데이 마라톤대회 (일)',
#   '대회날짜': '2025-09-14',
#   '지역': '금산군 금산인삼엑스포주차장',
#   '코스타입': '풀,하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?code=1482'},
#  {'대회제목': '2025 울진금강송배 전국마라톤대회',
#   '대회날짜': '2025-09-14',
#   '지역': '울진종합운동장',
#   '코스타입': '하프,10km,5km,7인1조 단체전',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.ujrun.kr'},
#  {'대회제목': '제4회 울산 동구 염포산 전국마라톤대회',
#   '대회날짜': '2025-09-14',
#   '지역': '서부시민운동장,봉수로 및 염포',
#   '코스타입': '11.2km',
#   '접수중여부': '',
#   '홈페이지': 'http://염포산마라톤대회.kr'},
#  {'대회제목': '2025 KTX 광명역 평화 마라톤',
#   '대회날짜': '2025-09-14',
#   '지역': 'KTX 광명역 일원',
#   '코스타입': '하프,10km,5km,가족런',
#   '접수중여부': '',
#   '홈페이지': 'http://gmrun.kr/'},
#  {'대회제목': '이봉주 보스턴제패기념 제25회 홍성마라톤',
#   '대회날짜': '2025-09-20',
#   '지역': '홍주종합경기장',
#   '코스타입': '하프,10km,6km건강코스,6km패밀리런',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://amarunhs.com/'},
#  {'대회제목': '2025 철원DMZ국제평화마라톤',
#   '대회날짜': '2025-09-21',
#   '지역': '철원군 고석정',
#   '코스타입': '풀,하프,10km,5.5km,코스모스 10리길 걷기',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://dmzrun.co.kr'},
#  {'대회제목': '2025 서울어스마라톤대회',
#   '대회날짜': '2025-09-21',
#   '지역': '서울 광화문 광장',
#   '코스타입': '하프,10km',
#   '접수중여부': '',
#   '홈페이지': 'http://earthmarathon.or.kr'},
#  {'대회제목': '제23회전국부부가족마라톤대회',
#   '대회날짜': '2025-09-21',
#   '지역': '전주천변',
#   '코스타입': '10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://jjrun.kr'},
#  {'대회제목': '제6회 천안삼거리 흥타령울트라마라톤',
#   '대회날짜': '2025-09-27',
#   '지역': '천안삼거리공원',
#   '코스타입': '100km,60km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.chultra.kr/'},
#  {'대회제목': '제6회 장수트레일레이스',
#   '대회날짜': '2025-09-27',
#   '지역': '장수종합경기장',
#   '코스타입': '100km,100M,38km',
#   '접수중여부': '',
#   '홈페이지': 'http://rocknrun.kr'},
#  {'대회제목': '2025 서산 코스모스 황금들녘 마라톤',
#   '대회날짜': '2025-09-28',
#   '지역': '서산스포츠테마파크',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://seosanrun.com/'},
#  {'대회제목': '2025 안동마라톤',
#   '대회날짜': '2025-09-28',
#   '지역': '안동시민운동장',
#   '코스타입': '풀,하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.admarathon.kr'},
#  {'대회제목': '제19회 달서하프마라톤',
#   '대회날짜': '2025-09-28',
#   '지역': '달서구 호림강나루공원',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.달서하프마라톤.kr'},
#  {'대회제목': '2025 봉화송이 전국마라톤',
#   '대회날짜': '2025-09-28',
#   '지역': '봉화공설운동장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://bonghwarun.kr'},
#  {'대회제목': '제18회 가평자라섬 전국마라톤대회',
#   '대회날짜': '2025-09-28',
#   '지역': '가평종합운동장',
#   '코스타입': '하프,10km,4.2km,4.2km가족런',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://gprun.com/'},
#  {'대회제목': '2025포항2차전지 전국마라톤대회',
#   '대회날짜': '2025-09-28',
#   '지역': '포항송도해수욕장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://energyrun.co.kr'},
#  {'대회제목': '제2회 울트라서울',
#   '대회날짜': '2025-10-03',
#   '지역': '시청 덕수궁돌담길',
#   '코스타입': '109.50.30.20.15',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://surally2406.webmaker21.kr/competition/outline?ca_id=02&wm_id=15'},
#  {'대회제목': '2025 한글런',
#   '대회날짜': '2025-10-09',
#   '지역': '세종시 중앙공원 도시축제마당',
#   '코스타입': '10.9km,5.15km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://hangeulrun.com'},
#  {'대회제목': '제1회 아산 이순신 트레일런 대회',
#   '대회날짜': '2025-10-11',
#   '지역': '아산 신정호 이순신 동상 앞',
#   '코스타입': '60km,44km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://isunshintrail.com'},
#  {'대회제목': '2025 해남 땅끝 전국마라톤',
#   '대회날짜': '2025-10-11',
#   '지역': '해남공설운동장',
#   '코스타입': '풀,하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://haenam.run1080.com/'},
#  {'대회제목': '제4회 무등산권 GEO 무등산마라톤대회',
#   '대회날짜': '2025-10-11',
#   '지역': '화순 금호스파리조트',
#   '코스타입': '하프,10km,5.18km,30km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.georun.kr/ko/'},
#  {'대회제목': '제8회 거제시장배 섬꽃 전국 마라톤',
#   '대회날짜': '2025-10-12',
#   '지역': '거제스포츠파크',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.geojerun.com/'},
#  {'대회제목': '2025 MBN 전국 나주 마라톤',
#   '대회날짜': '2025-10-12',
#   '지역': '나주종합스포츠파크',
#   '코스타입': '풀,하프,10km,5km,하프단체(남2,여1)',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://najumbnmarathon.com'},
#  {'대회제목': '2025 경포마라톤',
#   '대회날짜': '2025-10-18',
#   '지역': '경포해변 중앙광장',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.경포마라톤.com'},
#  {'대회제목': '제23회 청원생명쌀대청호마라톤',
#   '대회날짜': '2025-10-18',
#   '지역': '청주 상당구 문의체육원',
#   '코스타입': '풀,하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://race.cjsports.or.kr'},
#  {'대회제목': '제14회 광주평화통일마라톤',
#   '대회날짜': '2025-10-19',
#   '지역': '광주공항 주변도로',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.gjtongilmarathon.org/'},
#  {'대회제목': '제24회 대청호마라톤',
#   '대회날짜': '2025-10-19',
#   '지역': '대청공원',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://dcmarathon.or.kr'},
#  {'대회제목': '2025 제26회 울산마라톤',
#   '대회날짜': '2025-10-19',
#   '지역': '울산종합운동장(아산로)',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://ulsan.run'},
#  {'대회제목': '제7회 유성국화마라톤',
#   '대회날짜': '2025-10-26',
#   '지역': '유성구 유림공원 및 갑천변',
#   '코스타입': '10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://ysrun.co.kr/'},
#  {'대회제목': '2025무안해안 노을길 전국걷기 및 마라톤대회',
#   '대회날짜': '2025-11-01',
#   '지역': '무안낙지공원',
#   '코스타입': '10km,5km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.run1080.com/new/mini/index.php?sub=sub01_m01_c01&code=1493'},
#  {'대회제목': '2025 jtbc 서울마라톤',
#   '대회날짜': '2025-11-02',
#   '지역': '상암동 월드컵경기장',
#   '코스타입': '풀,10km',
#   '접수중여부': '',
#   '홈페이지': 'http://marathon.jtbc.com'},
#  {'대회제목': '제20회 울산인권마라톤',
#   '대회날짜': '2025-11-16',
#   '지역': '태화강 둔치',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://www.humanrun.org'},
#  {'대회제목': '제23회 상주 곶감 마라톤대회',
#   '대회날짜': '2025-11-16',
#   '지역': '상주시민운동장',
#   '코스타입': '풀,하프,10km,4km',
#   '접수중여부': '접수중',
#   '홈페이지': 'http://www.sangjugotgommarathon.com/'},
#  {'대회제목': '제3회 영남알프스 전국 하프마라톤',
#   '대회날짜': '2025-11-30',
#   '지역': '울주군 영남알프스 일원',
#   '코스타입': '하프,10km,5km',
#   '접수중여부': '',
#   '홈페이지': 'http://영남알프스.kr'}]

# %%
df = pd.DataFrame(race_data)
print(df.head(5))
# Out:
#                         대회제목        대회날짜            지역           코스타입 접수중여부  \
# 0                 제25회 여성마라톤  2025-05-03    평화의공원 평화광장   10km,5km,3km
# 1              2025 서울 유아차 런  2025-05-03         광화문광장            5km
# 2             제20회 보성 녹차 마라톤  2025-05-03       보성공설운동장  풀,하프,10km,5km
# 3  2025 우리은행배 제물포르네상스 국제 마라톤  2025-05-04      인천 상상플랫폼       10km,5km
# 4             2025 한강 하프 마라톤  2025-05-04  상암월드컵공원 평화광장    하프,10km,5km
#
#                                                 홈페이지
# 0                    http://www.womenmarathon.co.kr/
# 1      http://seoulstrollerrun.co.kr/apply/guide.php
# 2  http://boseong.run1080.com/index.php?sub=sub01...
# 3                               http://run.ito.or.kr
# 4                        http://www.seoulhalfrun.kr/

# %%
df.to_csv("marathon_schedule_2025.csv", index=False, encoding='utf-8-sig')
print("CSV 저장 완료! 항목 수:", len(df))
# Out:
# CSV 저장 완료! 항목 수: 132

# %%
# 날짜 추출 및 포맷 변경
from datetime import datetime


date_raw = tds[0].get_text(strip=True).split('(')[0].strip()  # "5/3"
# date_raw = tds[0].get_text()

print(date_raw)

# %%
date_obj = datetime.strptime(date_raw, "%m/%d")
race_date = f"2025-{date_obj.month:02}-{date_obj.day:02}"  # 연도는 임의 설정
print(race_date)

# %%
race_data
# Out:
# []
